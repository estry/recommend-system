# %%
import pandas as pd
import numpy as np
import math
import operator
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# 수정계획 1 : 상위 한개의 장르만 추출하는데 그게 아니라 상위 3개의 장르를 뽑아
#             그 중 선택한 장르와 가장 상관관계가 높은 장르를 추천하는 것을 어떨까?
class ModelFirst:
    def model1(self, selected_genres):
        df = pd.read_csv('/content/drive/MyDrive/data/user_pref.csv')
        corr = np.load('/content/drive/MyDrive/data/corr_save.npy')
        user_pref = df.to_numpy()
        transformer = StandardScaler()
        transformer.fit(user_pref)
        standard_user_pref = transformer.transform(user_pref)
        df = pd.DataFrame(user_pref, columns=df.columns)
        
        first_genre_index = df[selected_genres[0]].sort_values(ascending=False).head(1400).index
        second_genre_index = df[selected_genres[1]].sort_values(ascending=False).head(1400).index
        
        common_index = []
        for idx in first_genre_index:
            if idx in second_genre_index:
                common_index.append(idx)

        common_df = pd.DataFrame(index=range(0,len(common_index)), columns=df.columns)
        i = 0
        for idx in common_index:
            common_df.iloc[i] = df.iloc[idx]
            i = i + 1

        genre_title = df.columns
        genre_list = list(genre_title)
        first_idx = genre_list.index(selected_genres[0])
        second_idx = genre_list.index(selected_genres[1])
        co1 = corr[first_idx]
        co2 = corr[second_idx]

        select_values = common_df.values

        pred1 = (select_values * co1) / np.array([np.abs(co1).sum(axis=0)])
        pred1_df = pd.DataFrame(pred1, index=common_df.index, columns = common_df.columns)
        index = common_df.index
        result_dict = {}
        for i in index:
            sorted_tuple = pred1_df.iloc[i].sort_values(ascending=False)
            for genre in sorted_tuple.head(5).index.tolist():
                if genre not in result_dict and genre not in selected_genres:
                    result_dict[genre] = 0
                if genre not in selected_genres:
                    result_dict[genre] += 1
        sorted_result_dict = sorted(result_dict.items(), key=operator.itemgetter(1), reverse=True)
        recommend_genres = []
        for k,v in sorted_result_dict:
            if v >= 450:
                recommend_genres.append(k)

        pred2 = (select_values * co2) / np.array([np.abs(co2).sum(axis=0)])
        pred_df2 = pd.DataFrame(pred2, index=common_df.index, columns = common_df.columns)
        index = pred_df2.index
        result_dict = {}
        for i in index:
            sorted_tuple = pred_df2.iloc[i].sort_values(ascending=False)
            for genre in sorted_tuple.head(5).index.tolist():
                if genre not in result_dict and genre not in selected_genres:
                    result_dict[genre] = 0
                if genre not in selected_genres:
                    result_dict[genre] += 1
        sorted_result_dict = sorted(result_dict.items(), key=operator.itemgetter(1), reverse=True)
        for k,v in sorted_result_dict:
            if v >= 450 and k not in recommend_genres:
                recommend_genres.append(k)

        # print(recommend_genres)

        first_corr_list = []
        second_corr_list = []
        for g in recommend_genres:
            idx = genre_list.index(g)
            first_corr_value = corr[first_idx][idx]
            first_corr_list.append(first_corr_value)
            second_corr_value = corr[second_idx][idx]
            second_corr_list.append(second_corr_value)

        mean_corr_list = np.array(first_corr_list) + np.array(second_corr_list)
        mean_corr_list = mean_corr_list / 2

        max = mean_corr_list.max()
        mean_list = mean_corr_list.tolist()
        mean_idx = mean_list.index(max)

        result = recommend_genres[mean_idx]
        # print(result)

        temp = selected_genres
        result = list(result.split())
        result = temp+result
        return result

# %%
c = ModelFirst()
selected_genre = ['Horror', 'Thriller']
c.model1(selected_genre)
# Out:
# ['TV', 'Action', 'Crime', 'Adventure', 'Drama', 'Comedy']
# Action
# ['Horror', 'Thriller', 'Action']

# %%
new_movie_data = pd.read_csv('/content/drive/MyDrive/data/movieId&title.csv')
new_movie_data = new_movie_data[['id','genres']]

vector = TfidfVectorizer()
trans_data = np.array(new_movie_data['genres'].tolist())
movie_genre_tfidf = vector.fit_transform(trans_data).toarray()

SVD = TruncatedSVD(n_components=8)
matrix = SVD.fit_transform(movie_genre_tfidf.T)
matrix.shape

corr = np.corrcoef(matrix)
np.save('corr_save',corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6bac8ba54678> in <module>()
# ----> 1 new_movie_data = pd.read_csv('/content/drive/MyDrive/data/movieId&title.csv')
#       2 new_movie_data = new_movie_data[['id','genres']]
#       3
#       4 vector = TfidfVectorizer()
#       5 trans_data = np.array(new_movie_data['genres'].tolist())
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv('/content/drive/MyDrive/data/user_pref.csv')
genre_title = df.columns
genre_list = list(genre_title)

c = ModelFirst()
selected_genre = []
for i in range(len(genre_list)-1):
    for j in range(i, len(genre_list)):
        if genre_list[i] != genre_list[j]:
            selected_genre = [genre_list[i], genre_list[j]]
            result = c.model1(selected_genre)
            print(result)
# Out:
# ['Action', 'Adventure', 'Fiction']
# ['Action', 'Animation', 'Adventure']
# ['Action', 'Comedy', 'Family']
# ['Action', 'Crime', 'TV']
# ['Action', 'Documentary', 'Adventure']
# ['Action', 'Drama', 'Foreign']
# ['Action', 'Family', 'Adventure']
# ['Action', 'Fantasy', 'Adventure']
# ['Action', 'Fiction', 'Adventure']
# ['Action', 'Foreign', 'Adventure']
# ['Action', 'History', 'Foreign']
# ['Action', 'Horror', 'TV']
# ['Action', 'Movie', 'Adventure']
# ['Action', 'Music', 'History']
# ['Action', 'Mystery', 'Horror']
# ['Action', 'Romance', 'Adventure']
# ['Action', 'Science', 'Adventure']
# ['Action', 'TV', 'Horror']
# ['Action', 'Thriller', 'Adventure']
# ['Action', 'War', 'Adventure']
# ['Action', 'Western', 'Adventure']
# ['Adventure', 'Animation', 'Fantasy']
# ['Adventure', 'Comedy', 'Family']
# ['Adventure', 'Crime', 'Horror']
# ['Adventure', 'Documentary', 'Fiction']
# ['Adventure', 'Drama', 'Foreign']
# ['Adventure', 'Family', 'Fantasy']
# ['Adventure', 'Fantasy', 'Fiction']
# ['Adventure', 'Fiction', 'Science']
# ['Adventure', 'Foreign', 'Fantasy']
# ['Adventure', 'History', 'Foreign']
# ['Adventure', 'Horror', 'Action']
# ['Adventure', 'Movie', 'Fantasy']
# ['Adventure', 'Music', 'Fantasy']
# ['Adventure', 'Mystery', 'Action']
# ['Adventure', 'Romance', 'Fantasy']
# ['Adventure', 'Science', 'Fiction']
# ['Adventure', 'TV', 'Action']
# ['Adventure', 'Thriller', 'Fantasy']
# ['Adventure', 'War', 'Fantasy']
# ['Adventure', 'Western', 'Fiction']
# ['Animation', 'Comedy', 'Family']
# ['Animation', 'Crime', 'Horror']
# ['Animation', 'Documentary', 'Family']
# ['Animation', 'Drama', 'Foreign']
# ['Animation', 'Family', 'Fantasy']
# ['Animation', 'Fantasy', 'Adventure']
# ['Animation', 'Fiction', 'Fantasy']
# ['Animation', 'Foreign', 'Fantasy']
# ['Animation', 'History', 'Foreign']
# ['Animation', 'Horror', 'Action']
# ['Animation', 'Movie', 'Fantasy']
# ['Animation', 'Music', 'Fantasy']
# ['Animation', 'Mystery', 'Action']
# ['Animation', 'Romance', 'Fantasy']
# ['Animation', 'Science', 'Fantasy']
# ['Animation', 'TV', 'Action']
# ['Animation', 'Thriller', 'Fantasy']
# ['Animation', 'War', 'Fantasy']
# ['Animation', 'Western', 'Fantasy']
# ['Comedy', 'Crime', 'Mystery']
# ['Comedy', 'Documentary', 'Music']
# ['Comedy', 'Drama', 'Foreign']
# ['Comedy', 'Family', 'Animation']
# ['Comedy', 'Fantasy', 'Family']
# ['Comedy', 'Fiction', 'Family']
# ['Comedy', 'Foreign', 'Drama']
# ['Comedy', 'History', 'Drama']
# ['Comedy', 'Horror', 'Action']
# ['Comedy', 'Movie', 'Family']
# ['Comedy', 'Music', 'Family']
# ['Comedy', 'Mystery', 'Crime']
# ['Comedy', 'Romance', 'Drama']
# ['Comedy', 'Science', 'Family']
# ['Comedy', 'TV', 'Horror']
# ['Comedy', 'Thriller', 'Family']
# ['Comedy', 'War', 'Drama']
# ['Comedy', 'Western', 'Family']
# ['Crime', 'Documentary', 'Mystery']
# ['Crime', 'Drama', 'Mystery']
# ['Crime', 'Family', 'Horror']
# ['Crime', 'Fantasy', 'Horror']
# ['Crime', 'Fiction', 'Horror']
# ['Crime', 'Foreign', 'Drama']
# ['Crime', 'History', 'Mystery']
# ['Crime', 'Horror', 'TV']
# ['Crime', 'Movie', 'Mystery']
# ['Crime', 'Music', 'Drama']
# ['Crime', 'Mystery', 'TV']
# ['Crime', 'Romance', 'Mystery']
# ['Crime', 'Science', 'Horror']
# ['Crime', 'TV', 'Mystery']
# ['Crime', 'Thriller', 'Mystery']
# ['Crime', 'War', 'Mystery']
# ['Crime', 'Western', 'Horror']
# ['Documentary', 'Drama', 'History']
# ['Documentary', 'Family', 'Music']
# ['Documentary', 'Fantasy', 'Family']
# ['Documentary', 'Fiction', 'Science']
# ['Documentary', 'Foreign', 'Music']
# ['Documentary', 'History', 'Music']
# ['Documentary', 'Horror', 'Action']
# ['Documentary', 'Movie', 'Music']
# ['Documentary', 'Music', 'History']
# ['Documentary', 'Mystery', 'History']
# ['Documentary', 'Romance', 'Music']
# ['Documentary', 'Science', 'Fiction']
# ['Documentary', 'TV', 'History']
# ['Documentary', 'Thriller', 'Music']
# ['Documentary', 'War', 'History']
# ['Documentary', 'Western', 'Family']
# ['Drama', 'Family', 'Foreign']
# ['Drama', 'Fantasy', 'Foreign']
# ['Drama', 'Fiction', 'Foreign']
# ['Drama', 'Foreign', 'History']
# ['Drama', 'History', 'Foreign']
# ['Drama', 'Horror', 'TV']
# ['Drama', 'Movie', 'Foreign']
# ['Drama', 'Music', 'Foreign']
# ['Drama', 'Mystery', 'TV']
# ['Drama', 'Romance', 'Foreign']
# ['Drama', 'Science', 'Foreign']
# ['Drama', 'TV', 'Crime']
# ['Drama', 'Thriller', 'Foreign']
# ['Drama', 'War', 'Foreign']
# ['Drama', 'Western', 'Adventure']
# ['Family', 'Fantasy', 'Adventure']
# ['Family', 'Fiction', 'Fantasy']
# ['Family', 'Foreign', 'Fantasy']
# ['Family', 'History', 'Foreign']
# ['Family', 'Horror', 'Adventure']
# ['Family', 'Movie', 'Adventure']
# ['Family', 'Music', 'Foreign']
# ['Family', 'Mystery', 'Action']
# ['Family', 'Romance', 'Fantasy']
# ['Family', 'Science', 'Fantasy']
# ['Family', 'TV', 'Action']
# ['Family', 'Thriller', 'Adventure']
# ['Family', 'War', 'Fantasy']
# ['Family', 'Western', 'Adventure']
# ['Fantasy', 'Fiction', 'Adventure']
# ['Fantasy', 'Foreign', 'Adventure']
# ['Fantasy', 'History', 'Foreign']
# ['Fantasy', 'Horror', 'Action']
# ['Fantasy', 'Movie', 'Adventure']
# ['Fantasy', 'Music', 'Foreign']
# ['Fantasy', 'Mystery', 'Action']
# ['Fantasy', 'Romance', 'Adventure']
# ['Fantasy', 'Science', 'Adventure']
# ['Fantasy', 'TV', 'Action']
# ['Fantasy', 'Thriller', 'Adventure']
# ['Fantasy', 'War', 'Adventure']
# ['Fantasy', 'Western', 'Adventure']
# ['Fiction', 'Foreign', 'Fantasy']
# ['Fiction', 'History', 'Foreign']
# ['Fiction', 'Horror', 'Action']
# ['Fiction', 'Movie', 'Adventure']
# ['Fiction', 'Music', 'Fantasy']
# ['Fiction', 'Mystery', 'Action']
# ['Fiction', 'Romance', 'Fantasy']
# ['Fiction', 'Science', 'Adventure']
# ['Fiction', 'TV', 'Action']
# ['Fiction', 'Thriller', 'Adventure']
# ['Fiction', 'War', 'Adventure']
# ['Fiction', 'Western', 'Adventure']
# ['Foreign', 'History', 'Drama']
# ['Foreign', 'Horror', 'Action']
# ['Foreign', 'Movie', 'History']
# ['Foreign', 'Music', 'History']
# ['Foreign', 'Mystery', 'Drama']
# ['Foreign', 'Romance', 'Drama']
# ['Foreign', 'Science', 'Fantasy']
# ['Foreign', 'TV', 'Drama']
# ['Foreign', 'Thriller', 'History']
# ['Foreign', 'War', 'History']
# ['Foreign', 'Western', 'Adventure']
# ['History', 'Horror', 'Action']
# ['History', 'Movie', 'Foreign']
# ['History', 'Music', 'Foreign']
# ['History', 'Mystery', 'Drama']
# ['History', 'Romance', 'Foreign']
# ['History', 'Science', 'Foreign']
# ['History', 'TV', 'Drama']
# ['History', 'Thriller', 'Foreign']
# ['History', 'War', 'Foreign']
# ['History', 'Western', 'Foreign']
# ['Horror', 'Movie', 'Action']
# ['Horror', 'Music', 'History']
# ['Horror', 'Mystery', 'TV']
# ['Horror', 'Romance', 'Action']
# ['Horror', 'Science', 'Action']
# ['Horror', 'TV', 'Action']
# ['Horror', 'Thriller', 'Action']
# ['Horror', 'War', 'Action']
# ['Horror', 'Western', 'Action']
# ['Movie', 'Music', 'Foreign']
# ['Movie', 'Mystery', 'TV']
# ['Movie', 'Romance', 'Foreign']
# ['Movie', 'Science', 'Adventure']
# ['Movie', 'TV', 'Action']
# ['Movie', 'Thriller', 'Fantasy']
# ['Movie', 'War', 'Drama']
# ['Movie', 'Western', 'Adventure']
# ['Music', 'Mystery', 'History']
# ['Music', 'Romance', 'Foreign']
# ['Music', 'Science', 'Fantasy']
# ['Music', 'TV', 'History']
# ['Music', 'Thriller', 'Foreign']
# ['Music', 'War', 'Foreign']
# ['Music', 'Western', 'Adventure']
# ['Mystery', 'Romance', 'Drama']
# ['Mystery', 'Science', 'Action']
# ['Mystery', 'TV', 'Crime']
# ['Mystery', 'Thriller', 'TV']
# ['Mystery', 'War', 'TV']
# ['Mystery', 'Western', 'Action']
# ['Romance', 'Science', 'Fantasy']
# ['Romance', 'TV', 'War']
# ['Romance', 'Thriller', 'Foreign']
# ['Romance', 'War', 'Foreign']
# ['Romance', 'Western', 'Adventure']
# ['Science', 'TV', 'Action']
# ['Science', 'Thriller', 'Adventure']
# ['Science', 'War', 'Adventure']
# ['Science', 'Western', 'Adventure']
# ['TV', 'Thriller', 'Action']
# ['TV', 'War', 'Action']
# ['TV', 'Western', 'Action']
# ['Thriller', 'War', 'Drama']
# ['Thriller', 'Western', 'Adventure']
# ['War', 'Western', 'Adventure']
